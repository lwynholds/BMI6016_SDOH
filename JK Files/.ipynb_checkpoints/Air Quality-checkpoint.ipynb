# %% [markdown]
# # Data Imports

# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point

pd.set_option('display.max_columns', 70) # Set max display to 70 columns

# %% [markdown]
# ## Importing the 2020 air quality CSV from the [EPA website](https://aqs.epa.gov/aqsweb/airdata/download_files.html)
#
# https://aqs.epa.gov/aqsweb/airdata/download_files.html

# %%
air_quality_df = pd.read_csv("annual_conc_by_monitor_2020.csv") # Read in the CSV

# %%
# Filtering the AQ Data
air_quality_df = air_quality_df[air_quality_df['State Code'] == 49] # Utah
air_quality_df = air_quality_df[air_quality_df['Parameter Name'] == 'PM2.5 - Local Conditions'] # PM 2.5
air_quality_df = air_quality_df[air_quality_df['Pollutant Standard'].isin(['PM25 24-hour 2024', 'PM25 Annual 2024'])] # PM 2.5 standard effective 2024

# %%
air_quality_df.head()
# Out:
#        State Code  County Code  Site Num  Parameter Code  POC   Latitude  \
# 66556          49            5         7           88101    1  41.842649
# 66557          49            5         7           88101    1  41.842649
# 66558          49            5         7           88101    1  41.842649
# 66568          49            5         7           88101    1  41.842649
# 66569          49            5         7           88101    1  41.842649
#
#         Longitude  Datum            Parameter Name Sample Duration  \
# 66556 -111.852199  WGS84  PM2.5 - Local Conditions         24 HOUR
# 66557 -111.852199  WGS84  PM2.5 - Local Conditions         24 HOUR
# 66558 -111.852199  WGS84  PM2.5 - Local Conditions         24 HOUR
# 66568 -111.852199  WGS84  PM2.5 - Local Conditions         24 HOUR
# 66569 -111.852199  WGS84  PM2.5 - Local Conditions         24 HOUR
#
#       Pollutant Standard                     Metric Used  \
# 66556  PM25 24-hour 2024                      Daily Mean
# 66557  PM25 24-hour 2024                      Daily Mean
# 66558  PM25 24-hour 2024                      Daily Mean
# 66568   PM25 Annual 2024  Quarterly Means of Daily Means
# 66569   PM25 Annual 2024  Quarterly Means of Daily Means
#
#                                              Method Name  Year  \
# 66556  R & P Model 2025 PM-2.5 Sequential Air Sampler...  2020
# 66557  R & P Model 2025 PM-2.5 Sequential Air Sampler...  2020
# 66558  R & P Model 2025 PM-2.5 Sequential Air Sampler...  2020
# 66568  R & P Model 2025 PM-2.5 Sequential Air Sampler...  2020
# 66569  R & P Model 2025 PM-2.5 Sequential Air Sampler...  2020
#
#                   Units of Measure                 Event Type  \
# 66556  Micrograms/cubic meter (LC)            Events Excluded
# 66557  Micrograms/cubic meter (LC)            Events Included
# 66558  Micrograms/cubic meter (LC)  Concurred Events Excluded
# 66568  Micrograms/cubic meter (LC)            Events Included
# 66569  Micrograms/cubic meter (LC)            Events Excluded
#
#        Observation Count  Observation Percent Completeness Indicator  \
# 66556                350                   96                      Y
# 66557                353                   96                      Y
# 66558                353                   96                      Y
# 66568                353                   96                      Y
# 66569                350                   96                      Y
#
#        Valid Day Count  Required Day Count  Exceptional Data Count  \
# 66556              353                 366                       0
# 66557              353                 366                       3
# 66558              353                 366                       3
# 66568              353                 366                       3
# 66569              353                 366                       0
#
#        Null Data Count  Primary Exceedance Count  Secondary Exceedance Count  \
# 66556               13                       2.0                         2.0
# 66557               13                       5.0                         5.0
# 66558               13                       5.0                         5.0
# 66568               13                       NaN                         NaN
# 66569               13                       NaN                         NaN
#
#       Certification Indicator  Num Obs Below MDL  Arithmetic Mean  \
# 66556               Certified                  0         7.742000
# 66557               Certified                  0         8.109065
# 66558               Certified                  0         8.109065
# 66568               Certified                  0         8.109065
# 66569               Certified                  0         7.742000
#
#        Arithmetic Standard Dev  1st Max Value  1st Max DateTime  \
# 66556                 5.847565           39.6  2020-01-21 00:00
# 66557                 7.090248           61.6  2020-08-21 00:00
# 66558                 7.090248           61.6  2020-08-21 00:00
# 66568                 7.090248           61.6  2020-08-21 00:00
# 66569                 5.847565           39.6  2020-01-21 00:00
#
#        2nd Max Value  2nd Max DateTime  3rd Max Value  3rd Max DateTime  \
# 66556           35.6  2020-01-20 00:00           31.7  2020-12-31 00:00
# 66557           50.2  2020-08-22 00:00           41.0  2020-08-23 00:00
# 66558           50.2  2020-08-22 00:00           41.0  2020-08-23 00:00
# 66568           50.2  2020-08-22 00:00           41.0  2020-08-23 00:00
# 66569           35.6  2020-01-20 00:00           31.7  2020-12-31 00:00
#
#        4th Max Value  4th Max DateTime  1st Max Non Overlapping Value  \
# 66556           30.9  2020-09-07 00:00                            NaN
# 66557           39.6  2020-01-21 00:00                            NaN
# 66558           39.6  2020-01-21 00:00                            NaN
# 66568           39.6  2020-01-21 00:00                            NaN
# 66569           30.9  2020-09-07 00:00                            NaN
#
#       1st NO Max DateTime  2nd Max Non Overlapping Value 2nd NO Max DateTime  \
# 66556                 NaN                            NaN                 NaN
# 66557                 NaN                            NaN                 NaN
# 66558                 NaN                            NaN                 NaN
# 66568                 NaN                            NaN                 NaN
# 66569                 NaN                            NaN                 NaN
#
#        99th Percentile  98th Percentile  95th Percentile  90th Percentile  \
# 66556             30.9             24.1             19.5             15.0
# 66557             39.6             28.6             20.3             15.7
# 66558             39.6             28.6             20.3             15.7
# 66568             39.6             28.6             20.3             15.7
# 66569             30.9             24.1             19.5             15.0
#
#        75th Percentile  50th Percentile  10th Percentile Local Site Name  \
# 66556             10.0              6.1              2.2      Smithfield
# 66557             10.2              6.3              2.3      Smithfield
# 66558             10.2              6.3              2.3      Smithfield
# 66568             10.2              6.3              2.3      Smithfield
# 66569             10.0              6.1              2.2      Smithfield
#
#                   Address State Name County Name   City Name     CBSA Name  \
# 66556  675 West 220 North       Utah       Cache  Smithfield  Logan, UT-ID
# 66557  675 West 220 North       Utah       Cache  Smithfield  Logan, UT-ID
# 66558  675 West 220 North       Utah       Cache  Smithfield  Logan, UT-ID
# 66568  675 West 220 North       Utah       Cache  Smithfield  Logan, UT-ID
# 66569  675 West 220 North       Utah       Cache  Smithfield  Logan, UT-ID
#
#       Date of Last Change
# 66556          2024-08-07
# 66557          2024-08-07
# 66558          2024-08-07
# 66568          2024-08-07
# 66569          2024-08-07

# %% [markdown]
# ## Importing the shape file
#
# The shape files can be downloaded from:
# https://www.census.gov/geographies/mapping-files/time-series/geo/tiger-line-file.2020.html#list-tab-790442341
#
# We only added the relevant shape file to our GitHub as it would be too large with everything in it. We are using these files:
# * tl_2020_49_tract20.shp
# * tl_2020_49_tract20.shx
# * tl_2020_49_tract20.dbf
# * tl_2020_49_tract20.prj

# %%
# The shape file is in the 'tl_2020_49_all' folder -> tl_2020_49_tract20.shp
# If you want to run, you'll have to replace with your own file path
file_path = "C:/Users/joshu/Documents/GitHub/BMI6016_SDOH/tl_2020_49_all/tl_2020_49_tract20.shp"
census_tracts = gpd.read_file(file_path)

# %%
census_tracts.head()
# Out:
#   STATEFP20 COUNTYFP20 TRACTCE20      GEOID20  NAME20    NAMELSAD20 MTFCC20  \
# 0        49        049    000901  49049000901    9.01  Census Tract   G5020
# 1        49        049    002500  49049002500      25  Census Tract   G5020
# 2        49        049    003401  49049003401   34.01  Census Tract   G5020
# 3        49        049    010210  49049010210  102.10  Census Tract   G5020
# 4        49        049    000505  49049000505    5.05  Census Tract   G5020
#
#   FUNCSTAT20   ALAND20  AWATER20   INTPTLAT20    INTPTLON20  \
# 0          S   1686016         0  +40.3051285  -111.6922978
# 1          S   1034541         0  +40.2296149  -111.6497278
# 2          S   9085765     23788  +40.0560227  -111.7122570
# 3          S  15810476         0  +40.4005884  -111.7306856
# 4          S   3919712         0  +40.3700595  -111.7070846
#
#                                             geometry
# 0  POLYGON ((-111.70144 40.31183, -111.69972 40.3...
# 1  POLYGON ((-111.65689 40.22703, -111.65689 40.2...
# 2  POLYGON ((-111.745 40.04366, -111.74455 40.044...
# 3  POLYGON ((-111.77339 40.41553, -111.76899 40.4...
# 4  POLYGON ((-111.72677 40.37546, -111.72662 40.3...

# %%
print(census_tracts.crs)
# Convert the census_tract GeoDF from EPSG:4269 (NAD83) to EPSG:4326 (WGS 84)
# This will match the format of the geo_df
census_tracts = census_tracts.to_crs(epsg=4326) 
print(census_tracts.crs)
# Out:
# EPSG:4269
# EPSG:4326

# %%
# Creating point geometries from latitude and longitude

geometry = [Point(xy) for xy in zip(air_quality_df['Longitude'], air_quality_df['Latitude'])]
geo_df = gpd.GeoDataFrame(air_quality_df, geometry=geometry, crs="EPSG:4326")  # The air quality data is in WGS 84 (EPSG:4326)

# %%
# Spatial join between the point GeoDF and census tract DF
joined_df = gpd.sjoin(geo_df, census_tracts, predicate='within', how='left') # Using left join to keep all original data.

# %%
# Extract GEOID from joined GeoDF
if 'GEOID' in joined_df.columns:
    result_df = joined_df[['State Code', 'County Code', 'Site Num', 'Parameter Code', 'POC', 'Latitude', 'Longitude', 'GEOID']]
elif 'GEOID20' in joined_df.columns:
    result_df = joined_df[['State Code', 'County Code', 'Site Num', 'Parameter Code', 'POC', 'Latitude', 'Longitude', 'GEOID20']]
else:
    result_df = joined_df[['State Code', 'County Code', 'Site Num', 'Parameter Code', 'POC', 'Latitude', 'Longitude']] # if no GEOID information, keep original data.
    print("Warning: No GEOID or GEOID20 column found in census tract data.")

# %% [markdown]
# You can check the census tract by typing in the address to https://geomap.ffiec.gov/ffiecgeomap/

# %%
# Print head of joined_df with unique TRACTCE20 values (unique census tracts)
joined_df.loc[joined_df.drop_duplicates(subset='TRACTCE20').index].head()
# Out:
#        State Code  County Code  Site Num  Parameter Code  POC   Latitude  \
# 66556          49            5         7           88101    1  41.842649
# 66954          49           11         4           88101    1  40.902967
# 67076          49           13         2           88101    3  40.294178
# 67174          49           21         5           88101    1  37.747430
# 67216          49           35      2005           88101    4  40.598056
#
#         Longitude  Datum            Parameter Name Sample Duration  \
# 66556 -111.852199  WGS84  PM2.5 - Local Conditions         24 HOUR
# 66954 -111.884467  WGS84  PM2.5 - Local Conditions         24 HOUR
# 67076 -110.009732  WGS84  PM2.5 - Local Conditions   24-HR BLK AVG
# 67174 -113.055525  WGS84  PM2.5 - Local Conditions   24-HR BLK AVG
# 67216 -111.894167  WGS84  PM2.5 - Local Conditions   24-HR BLK AVG
#
#       Pollutant Standard Metric Used  \
# 66556  PM25 24-hour 2024  Daily Mean
# 66954  PM25 24-hour 2024  Daily Mean
# 67076  PM25 24-hour 2024  Daily Mean
# 67174  PM25 24-hour 2024  Daily Mean
# 67216  PM25 24-hour 2024  Daily Mean
#
#                                              Method Name  Year  \
# 66556  R & P Model 2025 PM-2.5 Sequential Air Sampler...  2020
# 66954  R & P Model 2025 PM-2.5 Sequential Air Sampler...  2020
# 67076                                                NaN  2020
# 67174                                                NaN  2020
# 67216                                                NaN  2020
#
#                   Units of Measure                 Event Type  \
# 66556  Micrograms/cubic meter (LC)            Events Excluded
# 66954  Micrograms/cubic meter (LC)                  No Events
# 67076  Micrograms/cubic meter (LC)                  No Events
# 67174  Micrograms/cubic meter (LC)                  No Events
# 67216  Micrograms/cubic meter (LC)  Concurred Events Excluded
#
#        Observation Count  Observation Percent Completeness Indicator  \
# 66556                350                   96                      Y
# 66954                325                   89                      Y
# 67076                366                  100                      Y
# 67174                366                  100                      Y
# 67216                363                   99                      Y
#
#        Valid Day Count  Required Day Count  Exceptional Data Count  \
# 66556              353                 366                       0
# 66954              325                 366                       0
# 67076              366                 366                       0
# 67174              366                 366                       0
# 67216              363                 366                       0
#
#        Null Data Count  Primary Exceedance Count  Secondary Exceedance Count  \
# 66556               13                       2.0                         2.0
# 66954               40                       0.0                         0.0
# 67076                0                       4.0                         4.0
# 67174                0                       0.0                         0.0
# 67216                0                       4.0                         4.0
#
#       Certification Indicator  Num Obs Below MDL  Arithmetic Mean  \
# 66556               Certified                  0         7.742000
# 66954               Certified                  0         7.083077
# 67076               Certified                  0         7.465301
# 67174               Certified                  0         5.383060
# 67216               Certified                  0         9.264463
#
#        Arithmetic Standard Dev  1st Max Value  1st Max DateTime  \
# 66556                 5.847565           39.6  2020-01-21 00:00
# 66954                 5.383427           32.3  2020-10-07 00:00
# 67076                 6.313076           45.3  2020-09-06 00:00
# 67174                 3.507251           28.7  2020-09-07 00:00
# 67216                 7.149932           49.3  2020-07-05 00:00
#
#        2nd Max Value  2nd Max DateTime  3rd Max Value  3rd Max DateTime  \
# 66556           35.6  2020-01-20 00:00           31.7  2020-12-31 00:00
# 66954           28.8  2020-10-06 00:00           27.4  2020-12-10 00:00
# 67076           44.6  2020-10-07 00:00           44.3  2020-09-07 00:00
# 67174           21.6  2020-10-06 00:00           19.4  2020-10-07 00:00
# 67216           48.7  2020-08-21 00:00           40.6  2020-09-07 00:00
#
#        4th Max Value  4th Max DateTime  1st Max Non Overlapping Value  \
# 66556           30.9  2020-09-07 00:00                            NaN
# 66954           26.1  2020-09-07 00:00                            NaN
# 67076           37.0  2020-10-08 00:00                            NaN
# 67174           18.1  2020-08-03 00:00                            NaN
# 67216           36.9  2020-08-22 00:00                            NaN
#
#       1st NO Max DateTime  2nd Max Non Overlapping Value 2nd NO Max DateTime  \
# 66556                 NaN                            NaN                 NaN
# 66954                 NaN                            NaN                 NaN
# 67076                 NaN                            NaN                 NaN
# 67174                 NaN                            NaN                 NaN
# 67216                 NaN                            NaN                 NaN
#
#        99th Percentile  98th Percentile  95th Percentile  90th Percentile  \
# 66556             30.9             24.1             19.5             15.0
# 66954             26.1             25.6             18.3             13.8
# 67076             37.0             23.2             19.9             15.1
# 67174             18.1             16.5             12.1              9.4
# 67216             36.9             31.2             24.1             17.8
#
#        75th Percentile  50th Percentile  10th Percentile     Local Site Name  \
# 66556             10.0              6.1              2.2          Smithfield
# 66954              8.7              5.8              2.2  Bountiful Viewmont
# 67076              8.9              5.5              2.4           Roosevelt
# 67174              6.5              4.6              2.3               Enoch
# 67216             11.2              7.0              3.2         Copper View
#
#                                     Address State Name County Name  \
# 66556                    675 West 220 North       Utah       Cache
# 66954  171 WEST 1370 NORTH, BOUNTIFUL, UTAH       Utah       Davis
# 67076                        290 S. 1000 W.       Utah    Duchesne
# 67174                   3840 North 325 East       Utah        Iron
# 67216                    8449 S. Monroe St.       Utah   Salt Lake
#
#         City Name             CBSA Name Date of Last Change  \
# 66556  Smithfield          Logan, UT-ID          2024-08-07
# 66954   Bountiful  Ogden-Clearfield, UT          2024-05-18
# 67076   Roosevelt                   NaN          2024-05-18
# 67174       Enoch        Cedar City, UT          2024-05-18
# 67216     Midvale    Salt Lake City, UT          2024-08-07
#
#                           geometry  index_right STATEFP20 COUNTYFP20  \
# 66556   POINT (-111.8522 41.84265)          258        49        005
# 66954  POINT (-111.88447 40.90297)          170        49        011
# 67076  POINT (-110.00973 40.29418)          287        49        013
# 67174  POINT (-113.05552 37.74743)           87        49        021
# 67216  POINT (-111.89417 40.59806)          472        49        035
#
#       TRACTCE20      GEOID20   NAME20    NAMELSAD20 MTFCC20 FUNCSTAT20  \
# 66556    000201  49005000201     2.01  Census Tract   G5020          S
# 66954    126600  49011126600     1266  Census Tract   G5020          S
# 67076    940502  49013940502  9405.02  Census Tract   G5020          S
# 67174    110201  49021110201  1102.01  Census Tract   G5020          S
# 67216    112402  49035112402  1124.02  Census Tract   G5020          S
#
#         ALAND20  AWATER20   INTPTLAT20    INTPTLON20
# 66556  40625920    200123  +41.8501637  -111.8559779
# 66954   2447881         0  +40.8999263  -111.8826698
# 67076  66640490     51513  +40.3115865  -110.0221147
# 67174  12397351         0  +37.7493853  -113.0545971
# 67216   2720633         0  +40.6002942  -111.8972171

# %%
# saving results
#result_df.to_csv("census_tract_results.csv", index=False)
